# %%
using Plots
using LinearAlgebra
using Revise
using Optim
using Zygote
using LaTeXStrings
using MultiFloats
using SparseIR
using Nevanlinna

# %%
T = BigFloat
# Out:
# BigFloat

# %%
beta::Float64 = 100
wmax::Float64 = 10
basis = FiniteTempBasisSet(Float64(beta), Float64(wmax), 1e-15)
# Out:
# FiniteTempBasisSet with β = 100.0, ωmax = 10.0

# %%
include("../flex_src/IRFLEX.jl")
# Out:
# WARNING: replacing module IRFLEX.
# Main.IRFLEX

# %%
nsize::Int64 = 1024
eta::Float64 = 0.01
t_pra::Float64 = 0.0
filling::Float64 = 1.0
U::Float64 = 0.5
hami::Function = (x,y) -> IRFLEX.single_Hami(x,y,t_pra)
lat = IRFLEX.SingleLatticeModel(nsize, filling, U, SparseIR.β(basis), hami)
;

# %%
function exact_suscep(qx, qy, omega, eta, nsize, beta, hami)
    chi::ComplexF64 = 0
    for ix in 1:nsize, iy in 1:nsize
        kx::Float64 = 2*π*(ix-1)/nsize
        ky::Float64 = 2*π*(iy-1)/nsize
        ek  = hami(kx,ky)
        ekq = hami(kx-qx,ky-qy)
        chi += -(IRFLEX.fermi_dirac(ekq,beta)-IRFLEX.fermi_dirac(ek,beta))/(omega+im*eta+ekq-ek)
    end
    chi = chi/(nsize*nsize)
    return chi
end
# Out:
# exact_suscep (generic function with 1 method)

# %%
rho(omega) = imag(exact_suscep(π,π,omega, eta, nsize, SparseIR.β(basis),hami))/(pi*tanh(0.5*SparseIR.β(basis)*omega))
# Out:
# rho (generic function with 1 method)

# %%
omegas = LinRange(-5, 5, 1000)
plot(omegas, rho.(omegas).*tanh.(0.5*beta*omegas), xlabel=latexstring("\\omega"), ylabel=latexstring("\\rho(\\omega)"))

# %%
rhol = [overlap(basis.basis_b.v[l], rho) for l in 1:length(basis.basis_b)]
chil = - basis.basis_b.s .* rhol

# %%
plot(yaxis=:log,ylims=(1e-16,10))
#plot()
plot!(real.(chil),label="chi_l")
plot!(real.(basis.basis_b.s),label="s")
# Out:
# SYSTEM: show(lasterr) caused an error
#
# Stacktrace:
#  [1] top-level scope
#    @ In[16]:1
#  [2] eval
#    @ ./boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1428

# %%
chiw = evaluate(basis.smpl_wn_f, chil)
hnw = (length(basis.smpl_wn_b.sampling_points)-1)÷2
# Out:
# UndefVarError: chil not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[17]:1
#  [2] eval
#    @ ./boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1428

# %%
plot(title="chisw_fermi")
plot!(real.(chiw[:]), label="real")
plot!(imag.(chiw[:]), label="imag")
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] findall(testf::Function, A::Vector{Dict{Symbol, Any}})
#    @ Base ./array.jl:2311
#  [2] process_sliced_series_attributes!(plt::Plots.Plot{Plots.GRBackend}, kw_list::Vector{Dict{Symbol, Any}})
#    @ Plots ~/.julia/packages/Plots/FCUr0/src/pipeline.jl:153
#  [3] _process_seriesrecipes!(plt::Any, kw_list::Any)
#    @ RecipesPipeline ~/.julia/packages/RecipesPipeline/OXGmH/src/series_recipe.jl:16
#  [4] recipe_pipeline!(plt::Any, plotattributes::Any, args::Any)
#    @ RecipesPipeline ~/.julia/packages/RecipesPipeline/OXGmH/src/RecipesPipeline.jl:97
#  [5] _plot!(plt::Plots.Plot, plotattributes::Any, args::Any)
#    @ Plots ~/.julia/packages/Plots/FCUr0/src/plot.jl:231
#  [6] plot(; kw::Base.Pairs{Symbol, V, Tuple{Vararg{Symbol, N}}, NamedTuple{names, T}} where {V, N, names, T<:Tuple{Vararg{Any, N}}})
#    @ Plots ~/.julia/packages/Plots/FCUr0/src/plot.jl:106
#  [7] top-level scope
#    @ In[18]:1
#  [8] eval
#    @ ./boot.jl:368 [inlined]
#  [9] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1428

# %%
sum_rule = real(dot(basis.basis_f.u(SparseIR.β(basis)), chil) + dot(basis.basis_f.u(0), chil))
# Out:
# UndefVarError: chil not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[19]:1
#  [2] eval
#    @ ./boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1428

# %%
setprecision(512)
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] top-level scope
#    @ In[20]:1
#  [2] eval
#    @ ./boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1428

# %%
input_chi  = Array{Complex{T}}(undef, hnw) 
input_smpl = Array{Complex{T}}(undef, hnw) 
;
# Out:
# UndefVarError: hnw not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[21]:1
#  [2] eval
#    @ ./boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1428

# %%
for i in 1:hnw
    input_smpl[i] = SparseIR.valueim(basis.smpl_wn_f.sampling_points[hnw+i], SparseIR.β(basis))
    input_chi[i]  = -chiw[hnw+i]
end
# Out:
# UndefVarError: hnw not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ ./In[22]:1
#  [2] eval
#    @ ./boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1428

# %%
N_real    =  6000
omega_max =  10.0
#eta       =  0.01
H_max     =  50
ab_coeff  = zeros(ComplexF64, 2*H_max) 
lambda    = 1e-5
#1000 → 2000
iter_tol  = 1000
N_imag    =  Nevanlinna.calc_opt_N_imag(hnw, input_smpl, input_chi)
#N_imag = hnw 
println("N_imag $(N_imag)")
# Out:
# UndefVarError: hnw not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[23]:9
#  [2] eval
#    @ ./boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1428

# %%
imaginary = Nevanlinna.ImagDomainData(input_smpl, input_chi, N_imag)
raw_reals = Nevanlinna.RealDomainData(N_real, omega_max, eta, sum_rule, T=T)
println(typeof(imaginary))
println(typeof(raw_reals))

phis = Nevanlinna.calc_phis(imaginary)
abcd = Nevanlinna.calc_abcd(imaginary, raw_reals, phis)
hardy_matrix = Nevanlinna.calc_hardy_matrix(raw_reals, H_max)

Nevanlinna.evaluation!(raw_reals, abcd, H_max, ab_coeff, hardy_matrix)
# Out:
# Pick matrix is positive semi-definite.
# ImagDomainData{BigFloat}
# RealDomainData{BigFloat}
# max_theta=0.0
# hardy optimization was success.
# true

# %%
@time sol = Nevanlinna.NevanlinnaSolver(N_imag, input_smpl, input_chi, N_real, omega_max, eta, sum_rule, H_max, iter_tol, lambda, true)
;
# Out:
# Pick matrix is positive semi-definite.
# H=1
# Iter     Function value   Gradient norm
#      0     5.049259e+02     7.006271e+01
#  * time: 0.015557050704956055
#      1     4.104250e+02     4.108822e+01
#  * time: 9.537883996963501
#      2     4.066656e+02     4.505710e+01
#  * time: 12.225700855255127
#      3     4.037888e+02     1.853471e+01
#  * time: 14.287835836410522
#      4     4.034795e+02     7.768617e+00
#  * time: 15.644892930984497
#      5     4.033076e+02     2.107659e+00
#  * time: 17.005944967269897
#      6     4.032537e+02     7.094049e-01
#  * time: 19.068285942077637
#      7     4.032491e+02     7.177273e-01
#  * time: 20.397003889083862
#      8     4.032475e+02     1.938747e-01
#  * time: 22.457778930664062
#      9     4.032473e+02     8.072725e-02
#     12     3.698987e+02     1.075472e-01
#  * time: 26.644705057144165
#     13     3.698986e+02     3.697682e-02
#  * time: 28.691622972488403
#     14     3.698986e+02     1.366038e-02
#  * time: 30.141263008117676
#     15     3.698986e+02     9.249268e-03
#  * time: 32.227774143218994
#     16     3.698986e+02     6.393378e-03
#  * time: 33.61859917640686
#     17     3.698986e+02     2.401751e-03
#  * time: 35.017565965652466
#     18     3.698986e+02     1.451821e-03
#  * time: 36.41046214103699
#     19     3.698986e+02     8.917563e-04
#  * time: 39.79991817474365
#     20     3.698986e+02     5.139709e-04
#  * time: 41.23727798461914
#     21     3.698986e+02     3.177117e-04
#  * time: 43.33552098274231
#     22     3.698986e+02     1.638172e-04
#  * time: 44.70179796218872
#     23     3.698986e+02     6.677137e-05
#  * time: 46.782979011535645
#     24     3.698986e+02     2.826433e-05
#  * time: 48.149259090423584
#     25     3.698986e+02     2.451604e-05
#  * time: 50.224684953689575
#     26     3.698986e+02     1.678428e-05
#  * time: 51.601186990737915
#     27     3.698986e+02     8.349816e-06
#  * time: 53.65836310386658
#     28     3.698986e+02     5.362065e-06
#  * time: 55.01263213157654
#     29     3.698986e+02     2.517280e-06
#  * time: 57.11829614639282
#     30     3.698986e+02     1.201667e-06
#  * time: 58.458178997039795
#     31     3.698986e+02     6.090923e-07
#  * time: 60.478471994400024
#     32     3.698986e+02     5.011992e-07
#  * time: 61.9064781665802
#     33     3.698986e+02     2.504531e-07
#  * time: 63.92845702171326
#     34     3.698986e+02     1.615454e-07
#  * time: 65.29669308662415
#     35     3.698986e+02     7.600288e-08
#  * time: 67.33396911621094
#     36     3.698986e+02     3.926721e-08
#  * time: 68.75299501419067
#     37     3.698986e+02     1.872978e-08
#  * time: 70.76953411102295
#     38     3.698986e+02     1.550179e-08
#  * time: 72.12649297714233
#     39     3.698986e+02     7.752093e-09
#  * time: 74.22943902015686
# max_theta=1.08279862565036541293017256281715950610913828975690450916367352104747410589924455679188079180511988128246204860931052623106929407828836015954126585336144277
# hardy optimization was failure.
#  76.065272 seconds (1.04 G allocations: 65.446 GiB, 22.76% gc time, 0.07% compilation time)

# %%
plot(xlim = [-0.1,5])
plot!(real.(raw_reals.freq), imag.(raw_reals.val/pi).*tanh.(0.5*SparseIR.β(basis)*real.(raw_reals.freq)))
plot!(real.(sol.reals.freq), imag.(sol.reals.val/pi).*tanh.(0.5*SparseIR.β(basis)*real.(raw_reals.freq)))

# %%
plot(xlim = [-1,1])
#plot!(real.(raw_reals.freq), imag.(raw_reals.val/pi).*tanh.(0.5*SparseIR.β(basis)*real.(raw_reals.freq)),label="non-opt", marker=:+)
plot!(real.(raw_reals.freq), imag.(raw_reals.val/pi).*tanh.(0.5*SparseIR.β(basis)*real.(raw_reals.freq)),label="non-opt")
#plot!(Float64.(real.((sol.reals.freq))), Float64.(imag.(sol.reals.val/pi)).*tanh.(0.5*SparseIR.β(basis)*real.(sol.reals.freq)),label="opt")
plot!(real.(exa_freq), imag.(exa_chi)/pi,label="exact")

# %%
plot(xlim = [-2,8])
plot!(real.(raw_reals.freq), imag.(raw_reals.val/pi),marker=:+)
#plot!(Float64.(real.((sol.reals.freq))), Float64.(imag.(sol.reals.val/pi)))

# %%
ComplexF64.(raw_reals.freq[1])
# Out:
# -10.0 + 0.01im
